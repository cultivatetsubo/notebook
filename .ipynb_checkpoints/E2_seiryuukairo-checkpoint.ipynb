# %%
import math
import numpy as np
from pandas import Series,DataFrame
import pandas as pd
import scipy.optimize
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline
from datetime import datetime as dt




V=np.loadtxt('E2RC2_V.txt').T
t=V[0][-200:]
v=V[1][-200:]
print('{},{}'.format(max(v),min(v)))
ripple=(max(v)-min(v))/(max(v)+min(v))*2
print(ripple)
print("1/fCR={}".format(1/50/674/51.4*1000000))
plt.plot(t,v,'o')
# Out:
# 18.69683,11.68702
# 0.46141683822162094
# 1/fCR=0.5773072082578024

# %%
import pandas as pd
df1 = pd.read_csv("RC_51_4_ver1.CSV")
V = np.array(df1.iloc[:,9])
T=np.array(df1.iloc[:,8])
ripple=(max(V)-min(V))/(max(V)+min(V))*2
print(ripple)
plt.plot(T,V,'o')
# Out:
# 0.5177609217474796
