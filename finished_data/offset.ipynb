# %%
import numpy as np
from pandas import Series,DataFrame
import pandas as pd
import scipy.optimize
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline
offset=np.loadtxt('offsettxt.txt').T
offset[0]=(offset[0]-offset[0][0])*0.001
plt.plot(offset[0],offset[1],label="offset-voltage")
plt.ylim([-0.5,0.5])
plt.ylabel('offset-voltage[V]')
plt.xlabel('time[ms]')
plt.title('offset-voltage')
plt.legend()
file1="offset.eps"
plt.savefig(file1)
plt.show()
